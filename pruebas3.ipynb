# %%
import pandas as pd
import numpy as np
from faker import Faker
import random
import datetime
import boto3
import psycopg2
import configparser

# %% [markdown]
# ### Creación del modelo de datos

# %%
rdsIdentifier = 'super-db' #nombre de la instancia

# %% [markdown]
# #### Cargamos archivo de configuraciones

# %%
config = configparser.ConfigParser()
config.read('escec2.cfg')
# Out:
# ['escec2.cfg']

# %% [markdown]
# ### Creamos Instancia de S3 y RDS

# %%
s3 = boto3.resource(
    service_name = 's3',
    region_name = 'us-east-1',
    aws_access_key_id = config.get('IAM', 'ACCESS_KEY'),
    aws_secret_access_key = config.get('IAM', 'SECRET_ACCESS_KEY')
)
aws_conn = boto3.client('rds', aws_access_key_id=config.get('IAM', 'ACCESS_KEY'),
                    aws_secret_access_key=config.get('IAM', 'SECRET_ACCESS_KEY'),
                    region_name='us-east-1')

# %% [markdown]
# #### Verificamos Instancias de RDS disponibles

# %%
rdsInstanceIds = []

response = aws_conn.describe_db_instances()
for resp in response['DBInstances']:
    rdsInstanceIds.append(resp['DBInstanceIdentifier'])
    db_instance_status = resp['DBInstanceStatus']

print(f"DBInstanceIds {rdsInstanceIds}")
# Out:
# DBInstanceIds ['super-db']

# %% [markdown]
# #### Creación de Servicio RDS

# %%
try:
    response = aws_conn.create_db_instance(
            AllocatedStorage=10,
            DBName=config.get('RDS_MYSQL', 'DB_NAME'),
            DBInstanceIdentifier=rdsIdentifier,
            DBInstanceClass="db.t3.micro",
            Engine="mysql",
            MasterUsername=config.get('RDS_MYSQL', 'DB_USER'),
            MasterUserPassword=config.get('RDS_MYSQL', 'DB_PASSWORD'),
            BackupRetentionPeriod=0, #para evitar los backups y que nos cobren
            Port=int(config.get('RDS_MYSQL', 'DB_PORT')),
            VpcSecurityGroupIds=[config.get('VPC', 'SECURITY_GROUP')],
            PubliclyAccessible=True
        )
    print(response)
except aws_conn.exceptions.DBInstanceAlreadyExistsFault as ex:
    print("La Instancia de Base de Datos ya Existe.")
# Out:
# La Instancia de Base de Datos ya Existe.

# %% [markdown]
# ##### Obtenemos URL del Host

# %%
try:
     instances = aws_conn.describe_db_instances(DBInstanceIdentifier=rdsIdentifier)
     RDS_HOST = instances.get('DBInstances')[0].get('Endpoint').get('Address')
     print(RDS_HOST)
except Exception as ex:
     print("La instancia de base de datos no existe o aun no se ha terminado de crear.")
     print(ex)
# Out:
# super-db.cio9bwv4hzyt.us-east-1.rds.amazonaws.com

# %% [markdown]
# #### Conexión a Base de Datos desde Python

# %%
import querie_super

# %%
import querie_super
import mysql.connector as mysqlC
try:
    myDw = mysqlC.connect(
    host=RDS_HOST, 
    user=config.get('RDS_MYSQL', 'DB_USER'),
    password=config.get('RDS_MYSQL', 'DB_PASSWORD'),
    database=config.get('RDS_MYSQL', 'DB_NAME')
    )

    mycursor = myDw.cursor()
    mycursor.execute(querie_super.DDL_QUERY_SUPER, multi=True)
    myDw.commit()
    print("Data Warehouse Creado Exitosamente")
except Exception as ex:
    print("ERROR: Error al crear la base de datos.")
    print(ex)

#Aunque nos de un error, verificar en DBeaver si se creó el query y las tablas
# Out:
# ERROR: Error al crear la base de datos.
# 1050 (42S01): Table 'Ubicacion' already exists

# %% [markdown]
# #### Driver MYSQL

# %%
mysql_driver = f"""mysql+pymysql://{config.get('RDS_MYSQL', 'DB_USER')}:{config.get('RDS_MYSQL', 'DB_PASSWORD')}@{RDS_HOST}:{config.get('RDS_MYSQL', 'DB_PORT')}/{config.get('RDS_MYSQL', 'DB_NAME')}"""

# %%
sql_query = 'SELECT * FROM Ubicacion;'
df_ubicacion = pd.read_sql(sql_query, mysql_driver)
df_ubicacion.head()
# Out:
#    ID_Ubicacion  Codigo_postal           Pais      Estado         Ciudad
# 0             1        55407.0  United States   Minnesota    Minneapolis
# 1             2        94109.0  United States  California  San Francisco
# 2             3        94122.0  United States  California  San Francisco
# 3             4        78664.0  United States       Texas     Round Rock
# 4             5        10011.0  United States    New York  New York City

# %% [markdown]
# #### Creamos el bucket y cargamos los datos

# %%
# Nombre del bucket
bucket_name = 'datos-super-edgar'

# %%
# Creación del bucket
s3.create_bucket(Bucket=bucket_name)

# documentos
file_name = 'dim_date.csv'
file_name2 = 'SuperStoreOutput.csv'

# Nombre del archivo csv en el bucket
s3_file_name = 'dim_date_super.csv'
s3_file_name2 = 'SuperStoreOutput.csv'

# Metiendo los archivos al bucket
s3.upload_file(file_name, bucket_name, s3_file_name)
s3.upload_file(file_name2, bucket_name, s3_file_name2)

#Acabo de cargar los datos de fechas y la base de datos principal
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8384\1422615389.py in <module>
#      11
#      12 # Metiendo los archivos al bucket
# ---> 13 s3.upload_file(file_name, bucket_name, s3_file_name)
#      14 s3.upload_file(file_name2, bucket_name, s3_file_name2)
#      15
#
# AttributeError: 's3.ServiceResource' object has no attribute 'upload_file'

# %%
for bucket in s3.buckets.all():
    S3_BUCKET_NAME = bucket.name
    print(bucket.name)
# Out:
# bucket-v-23000966
# datos-super-edgar

# %%
#extraemos todo lo que está en el bucket
remoteFileList = []
for objt in s3.Bucket(bucket_name).objects.all():
    remoteFileList.append(objt.key)

remoteFileList
# Out:
# ['SuperStoreOutput.csv', 'dim_date_super.csv']

# %% [markdown]
# #### Leemos archivo del bucket de S3

# %%
# Cargamos el data frame de supermercado
file1 = s3.Bucket(bucket_name).Object('SuperStoreOutput.csv').get()
tabla_super= pd.read_csv(file1['Body'])
tabla_super.head()
# Out:
#    Row ID        Order ID             Order Date              Ship Date  \
# 0    1160  CA-2018-147039  6/29/2018 12:00:00 AM   7/4/2018 12:00:00 AM
# 1    1161  CA-2018-147039  6/29/2018 12:00:00 AM   7/4/2018 12:00:00 AM
# 2    1300  CA-2016-121391  10/4/2016 12:00:00 AM  10/7/2016 12:00:00 AM
# 3    2230  CA-2015-128055  3/31/2015 12:00:00 AM   4/5/2015 12:00:00 AM
# 4    2231  CA-2015-128055  3/31/2015 12:00:00 AM   4/5/2015 12:00:00 AM
#
#         Ship Mode Customer ID Customer Name   Segment        Country  \
# 0  Standard Class    AA-10315    Alex Avila  Consumer  United States
# 1  Standard Class    AA-10315    Alex Avila  Consumer  United States
# 2     First Class    AA-10315    Alex Avila  Consumer  United States
# 3  Standard Class    AA-10315    Alex Avila  Consumer  United States
# 4  Standard Class    AA-10315    Alex Avila  Consumer  United States
#
#             City  ... Postal Code   Region       Product ID         Category  \
# 0    Minneapolis  ...     55407.0  Central  OFF-AP-10000576  Office Supplies
# 1    Minneapolis  ...     55407.0  Central  OFF-BI-10004654  Office Supplies
# 2  San Francisco  ...     94109.0     West  OFF-ST-10001590  Office Supplies
# 3  San Francisco  ...     94122.0     West  OFF-BI-10004390  Office Supplies
# 4  San Francisco  ...     94122.0     West  OFF-AP-10002765  Office Supplies
#
#   Sub-Category                                       Product Name   Sales  \
# 0   Appliances               Belkin 325VA UPS Surge Protector, 6'  362.94
# 1      Binders  Avery Binding System Hidden Tab Executive Styl...   11.54
# 2      Storage  Tenex Personal Project File with Scoop Front D...   26.96
# 3      Binders            GBC DocuBind 200 Manual Binding Machine  673.57
# 4   Appliances  Fellowes Advanced Computer Series Surge Protec...   52.98
#
#    Quantity  Discount  Profit
# 0         3       0.0   90.74
# 1         2       0.0    5.77
# 2         2       0.0    7.01
# 3         2       0.2  252.59
# 4         2       0.0   14.83
#
# [5 rows x 21 columns]

# %%
# Cargamos el data frame de fechas
file2 = s3.Bucket(bucket_name).Object('dim_date_super.csv').get()
fechas= pd.read_csv(file2['Body'])
fechas.head()
# Out:
#    date_key full_date  day_of_week  day_num_in_month  day_num_overall  \
# 0  20150101  1/1/2015            4                 1                1
# 1  20150102  1/2/2015            5                 2                2
# 2  20150103  1/3/2015            6                 3                3
# 3  20150104  1/4/2015            7                 4                4
# 4  20150105  1/5/2015            1                 5                5
#
#    day_name day_abbrev weekday_flag  week_num_in_year  week_num_overall  ...  \
# 0  Thursday        Thu      Weekday                 1                 1  ...
# 1    Friday        Fri      Weekday                 1                 1  ...
# 2  Saturday        Sat      Weekend                 1                 1  ...
# 3    Sunday        Sun      Weekend                 1                 1  ...
# 4    Monday        Mon      Weekday                 2                 2  ...
#
#   month_name  month_abbrev  quarter  year  yearmo fiscal_month  \
# 0    January           Jan        1  2015  201501            7
# 1    January           Jan        1  2015  201501            7
# 2    January           Jan        1  2015  201501            7
# 3    January           Jan        1  2015  201501            7
# 4    January           Jan        1  2015  201501            7
#
#    fiscal_quarter  fiscal_year  last_day_in_month_flag  same_day_year_ago_date
# 0               3         2015           Not Month End                1/1/2014
# 1               3         2015           Not Month End                1/2/2014
# 2               3         2015           Not Month End                1/3/2014
# 3               3         2015           Not Month End                1/4/2014
# 4               3         2015           Not Month End                1/5/2014
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Limpiamos las tablas para ser ingresadas a las dimensiones y hechos (Procesamiento)

# %% [markdown]
# #### Creamos tabla para cliente e insertamos en la dimensión

# %%
tabla_cl = tabla_super.loc[:, ['Customer ID','Customer Name', 'Segment']]

nombres_cl = {'Customer ID': 'Id_cliente', 'Customer Name': 'Nombre', 'Segment': 'Segmento'}
tabla_cl.rename(columns = nombres_cl, inplace = True)

tabla_clientes= tabla_cl.drop_duplicates()
tabla_clientes.head()
# Out:
#    Id_cliente         Nombre  Segmento
# 0    AA-10315     Alex Avila  Consumer
# 11   AA-10375   Allen Armold  Consumer
# 26   AA-10480   Andrew Allen  Consumer
# 38   AA-10645  Anna Andreadi  Consumer
# 56   AB-10015  Aaron Bergman  Consumer

# %%
#insertamos en dimension de cliente
tabla_clientes.to_sql('Cliente', mysql_driver, index=False, if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# c:\Users\fahv1\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1798                 if not evt_handled:
# -> 1799                     self.dialect.do_executemany(
#    1800                         cursor, statement, parameters, context
#
# c:\Users\fahv1\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     192     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 193         rowcount = cursor.executemany(statement, parameters)
#     194         if context is not None:
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     186             assert q_values[0] == "(" and q_values[-1] == ")"
# --> 187             return self._do_execute_many(
#     188                 q_prefix,
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     224             sql += v
# --> 225         rows += self.execute(sql + postfix)
#     226         self.rowcount = rows
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     157
# --> 158         result = self._query(query)
#     159         self._executed = query
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     324         self._clear_result()
# --> 325         conn.query(q)
#     326         self._do_get_result()
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     548         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 549         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     550         return self._affected_rows
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     778             result = MySQLResult(self)
# --> 779             result.read()
#     780         self._result = result
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1156         try:
# -> 1157             first_packet = self.connection._read_packet()
#    1158
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     728                 self._result.unbuffered_active = False
# --> 729             packet.raise_for_error()
#     730         return packet
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# IntegrityError: (1062, "Duplicate entry 'AA-10315' for key 'Cliente.PRIMARY'")
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8384\1524484519.py in <module>
#       1 #insertamos en dimension de cliente
# ----> 2 tabla_clientes.to_sql('Cliente', mysql_driver, index=False, if_exists='append')
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2949         from pandas.io import sql
#    2950
# -> 2951         return sql.to_sql(
#    2952             self,
#    2953             name,
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     696         )
#     697
# --> 698     return pandas_sql.to_sql(
#     699         frame,
#     700         name,
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1740         )
#    1741
# -> 1742         total_inserted = sql_engine.insert_records(
#    1743             table=table,
#    1744             con=self.connectable,
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1333                 raise ValueError("inf cannot be used with MySQL") from err
#    1334             else:
# -> 1335                 raise err
#    1336
#    1337
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1323
#    1324         try:
# -> 1325             return table.insert(chunksize=chunksize, method=method)
#    1326         except exc.SQLAlchemyError as err:
#    1327             # GH34431
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     949
#     950                 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# --> 951                 num_inserted = exec_insert(conn, keys, chunk_iter)
#     952                 # GH 46891
#     953                 if is_integer(num_inserted):
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     856         """
#     857         data = [dict(zip(keys, row)) for row in data_iter]
# --> 858         result = conn.execute(self.table.insert(), data)
#     859         return result.rowcount
#     860
#
# c:\Users\fahv1\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1304             )
#    1305         else:
# -> 1306             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1307
#    1308     def _execute_function(self, func, multiparams, params, execution_options):
#
# c:\Users\fahv1\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     330     ):
#     331         if _force or self.supports_execution:
# --> 332             return connection._execute_clauseelement(
#     333                 self, multiparams, params, execution_options
#     334             )
#
# c:\Users\fahv1\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1496             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1497         )
# -> 1498         ret = self._execute_context(
#    1499             dialect,
#    1500             dialect.execution_ctx_cls._init_compiled,
#
# c:\Users\fahv1\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1860
#    1861         except BaseException as e:
# -> 1862             self._handle_dbapi_exception(
#    1863                 e, statement, parameters, cursor, context
#    1864             )
#
# c:\Users\fahv1\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042             elif should_wrap:
# -> 2043                 util.raise_(
#    2044                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045                 )
#
# c:\Users\fahv1\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206
#     207         try:
# --> 208             raise exception
#     209         finally:
#     210             # credit to
#
# c:\Users\fahv1\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1797                             break
#    1798                 if not evt_handled:
# -> 1799                     self.dialect.do_executemany(
#    1800                         cursor, statement, parameters, context
#    1801                     )
#
# c:\Users\fahv1\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     191
#     192     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 193         rowcount = cursor.executemany(statement, parameters)
#     194         if context is not None:
#     195             context._rowcount = rowcount
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     185             q_postfix = m.group(3) or ""
#     186             assert q_values[0] == "(" and q_values[-1] == ")"
# --> 187             return self._do_execute_many(
#     188                 q_prefix,
#     189                 q_values,
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     223                 sql += b","
#     224             sql += v
# --> 225         rows += self.execute(sql + postfix)
#     226         self.rowcount = rows
#     227         return rows
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     156         query = self.mogrify(query, args)
#     157
# --> 158         result = self._query(query)
#     159         self._executed = query
#     160         return result
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     323         conn = self._get_db()
#     324         self._clear_result()
# --> 325         conn.query(q)
#     326         self._do_get_result()
#     327         return self.rowcount
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     547             sql = sql.encode(self.encoding, "surrogateescape")
#     548         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 549         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     550         return self._affected_rows
#     551
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     777         else:
#     778             result = MySQLResult(self)
# --> 779             result.read()
#     780         self._result = result
#     781         if result.server_status is not None:
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1155     def read(self):
#    1156         try:
# -> 1157             first_packet = self.connection._read_packet()
#    1158
#    1159             if first_packet.is_ok_packet():
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     727             if self._result is not None and self._result.unbuffered_active is True:
#     728                 self._result.unbuffered_active = False
# --> 729             packet.raise_for_error()
#     730         return packet
#     731
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     219         if DEBUG:
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#     223     def dump(self):
#
# c:\Users\fahv1\anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     141     if errorclass is None:
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# IntegrityError: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'AA-10315' for key 'Cliente.PRIMARY'")
# [SQL: INSERT INTO `Cliente` (`Id_cliente`, `Nombre`, `Segmento`) VALUES (%(Id_cliente)s, %(Nombre)s, %(Segmento)s)]
# [parameters: ({'Id_cliente': 'AA-10315', 'Nombre': 'Alex Avila', 'Segmento': 'Consumer'}, {'Id_cliente': 'AA-10375', 'Nombre': 'Allen Armold', 'Segmento': 'Consumer'}, {'Id_cliente': 'AA-10480', 'Nombre': 'Andrew Allen', 'Segmento': 'Consumer'}, {'Id_cliente': 'AA-10645', 'Nombre': 'Anna Andreadi', 'Segmento': 'Consumer'}, {'Id_cliente': 'AB-10015', 'Nombre': 'Aaron Bergman', 'Segmento': 'Consumer'}, {'Id_cliente': 'AB-10060', 'Nombre': 'Adam Bellavance', 'Segmento': 'Home Office'}, {'Id_cliente': 'AB-10105', 'Nombre': 'Adrian Barton', 'Segmento': 'Consumer'}, {'Id_cliente': 'AB-10150', 'Nombre': 'Aimee Bixby', 'Segmento': 'Consumer'}  ... displaying 10 of 793 total bound parameter sets ...  {'Id_cliente': 'ZC-21910', 'Nombre': 'Zuschuss Carroll', 'Segmento': 'Consumer'}, {'Id_cliente': 'ZD-21925', 'Nombre': 'Zuschuss Donatelli', 'Segmento': 'Consumer'})]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %% [markdown]
# #### Creamos tabla para producto

# %%
tabla_pr = tabla_super.loc[:, ['Product ID','Category', 'Sub-Category', 'Product Name']]
tabla_producto= tabla_pr.drop_duplicates()

tabla_producto.head()
# Out:
#         Product ID         Category Sub-Category  \
# 0  OFF-AP-10000576  Office Supplies   Appliances
# 1  OFF-BI-10004654  Office Supplies      Binders
# 2  OFF-ST-10001590  Office Supplies      Storage
# 3  OFF-BI-10004390  Office Supplies      Binders
# 4  OFF-AP-10002765  Office Supplies   Appliances
#
#                                         Product Name
# 0               Belkin 325VA UPS Surge Protector, 6'
# 1  Avery Binding System Hidden Tab Executive Styl...
# 2  Tenex Personal Project File with Scoop Front D...
# 3            GBC DocuBind 200 Manual Binding Machine
# 4  Fellowes Advanced Computer Series Surge Protec...

# %% [markdown]
# #### Creamos tabla para Ubicación

# %%
tabla_ub = tabla_super.loc[:, ['Postal Code','Country', 'State', 'City']]
tabla_ubicacion= tabla_ub.drop_duplicates()

tabla_ubicacion.head()
# Out:
#    Postal Code        Country       State           City
# 0      55407.0  United States   Minnesota    Minneapolis
# 2      94109.0  United States  California  San Francisco
# 3      94122.0  United States  California  San Francisco
# 5      78664.0  United States       Texas     Round Rock
# 9      10011.0  United States    New York  New York City

# %% [markdown]
# #### Creamos tabla para fechas de orden

# %%
tabla_fechas = fechas.loc[:, ['date_key', 'full_date','day_of_week', 'day_num_in_month', 'day_name', 'weekday_flag','month_name','month_abbrev','year']]

tabla_fechas.head()
# Out:
#    date_key full_date  day_of_week  day_num_in_month  day_name weekday_flag  \
# 0  20150101  1/1/2015            4                 1  Thursday      Weekday
# 1  20150102  1/2/2015            5                 2    Friday      Weekday
# 2  20150103  1/3/2015            6                 3  Saturday      Weekend
# 3  20150104  1/4/2015            7                 4    Sunday      Weekend
# 4  20150105  1/5/2015            1                 5    Monday      Weekday
#
#   month_name month_abbrev  year
# 0    January          Jan  2015
# 1    January          Jan  2015
# 2    January          Jan  2015
# 3    January          Jan  2015
# 4    January          Jan  2015

# %% [markdown]
# ### Comenzamos con proceso para carga hacia tabla de hechos

# %%
tabla_super = tabla_super.drop('Ship Mode',axis=1)
tabla_super
# Out:
#       Row ID        Order ID             Order Date              Ship Date  \
# 0       1160  CA-2018-147039  6/29/2018 12:00:00 AM   7/4/2018 12:00:00 AM
# 1       1161  CA-2018-147039  6/29/2018 12:00:00 AM   7/4/2018 12:00:00 AM
# 2       1300  CA-2016-121391  10/4/2016 12:00:00 AM  10/7/2016 12:00:00 AM
# 3       2230  CA-2015-128055  3/31/2015 12:00:00 AM   4/5/2015 12:00:00 AM
# 4       2231  CA-2015-128055  3/31/2015 12:00:00 AM   4/5/2015 12:00:00 AM
# ...      ...             ...                    ...                    ...
# 9989    3815  CA-2017-152471   7/8/2017 12:00:00 AM   7/8/2017 12:00:00 AM
# 9990    3816  CA-2017-152471   7/8/2017 12:00:00 AM   7/8/2017 12:00:00 AM
# 9991    5898  CA-2017-167682   4/3/2017 12:00:00 AM   4/9/2017 12:00:00 AM
# 9992    5899  CA-2017-167682   4/3/2017 12:00:00 AM   4/9/2017 12:00:00 AM
# 9993    8342  CA-2018-141481  6/11/2018 12:00:00 AM  6/14/2018 12:00:00 AM
#
#      Customer ID       Customer Name   Segment        Country           City  \
# 0       AA-10315          Alex Avila  Consumer  United States    Minneapolis
# 1       AA-10315          Alex Avila  Consumer  United States    Minneapolis
# 2       AA-10315          Alex Avila  Consumer  United States  San Francisco
# 3       AA-10315          Alex Avila  Consumer  United States  San Francisco
# 4       AA-10315          Alex Avila  Consumer  United States  San Francisco
# ...          ...                 ...       ...            ...            ...
# 9989    ZD-21925  Zuschuss Donatelli  Consumer  United States   Jacksonville
# 9990    ZD-21925  Zuschuss Donatelli  Consumer  United States   Jacksonville
# 9991    ZD-21925  Zuschuss Donatelli  Consumer  United States       Richmond
# 9992    ZD-21925  Zuschuss Donatelli  Consumer  United States       Richmond
# 9993    ZD-21925  Zuschuss Donatelli  Consumer  United States    Los Angeles
#
#            State  Postal Code   Region       Product ID         Category  \
# 0      Minnesota      55407.0  Central  OFF-AP-10000576  Office Supplies
# 1      Minnesota      55407.0  Central  OFF-BI-10004654  Office Supplies
# 2     California      94109.0     West  OFF-ST-10001590  Office Supplies
# 3     California      94122.0     West  OFF-BI-10004390  Office Supplies
# 4     California      94122.0     West  OFF-AP-10002765  Office Supplies
# ...          ...          ...      ...              ...              ...
# 9989     Florida      32216.0    South  TEC-PH-10002824       Technology
# 9990     Florida      32216.0    South  OFF-PA-10004965  Office Supplies
# 9991     Indiana      47374.0  Central  FUR-FU-10003799        Furniture
# 9992     Indiana      47374.0  Central  TEC-PH-10000673       Technology
# 9993  California      90036.0     West  OFF-AP-10004532  Office Supplies
#
#      Sub-Category                                       Product Name   Sales  \
# 0      Appliances               Belkin 325VA UPS Surge Protector, 6'  362.94
# 1         Binders  Avery Binding System Hidden Tab Executive Styl...   11.54
# 2         Storage  Tenex Personal Project File with Scoop Front D...   26.96
# 3         Binders            GBC DocuBind 200 Manual Binding Machine  673.57
# 4      Appliances  Fellowes Advanced Computer Series Surge Protec...   52.98
# ...           ...                                                ...     ...
# 9989       Phones           Jabra SPEAK 410 Multidevice Speakerphone  823.96
# 9990        Paper                                         Xerox 1921   15.98
# 9991  Furnishings                     Seth Thomas 13 1/2" Wall Clock   71.12
# 9992       Phones     Plantronics Voyager Pro HD - Bluetooth Headset  259.96
# 9993   Appliances  Kensington 6 Outlet Guardian Standard Surge Pr...   61.44
#
#       Quantity  Discount  Profit
# 0            3       0.0   90.74
# 1            2       0.0    5.77
# 2            2       0.0    7.01
# 3            2       0.2  252.59
# 4            2       0.0   14.83
# ...        ...       ...     ...
# 9989         5       0.2   51.50
# 9990         2       0.2    4.99
# 9991         4       0.0   22.05
# 9992         4       0.0  124.78
# 9993         3       0.0   16.59
#
# [9994 rows x 20 columns]

# %%
tabla_super = tabla_super.drop('Ship Date',axis=1)
tabla_super
# Out:
#       Row ID        Order ID             Order Date Customer ID  \
# 0       1160  CA-2018-147039  6/29/2018 12:00:00 AM    AA-10315
# 1       1161  CA-2018-147039  6/29/2018 12:00:00 AM    AA-10315
# 2       1300  CA-2016-121391  10/4/2016 12:00:00 AM    AA-10315
# 3       2230  CA-2015-128055  3/31/2015 12:00:00 AM    AA-10315
# 4       2231  CA-2015-128055  3/31/2015 12:00:00 AM    AA-10315
# ...      ...             ...                    ...         ...
# 9989    3815  CA-2017-152471   7/8/2017 12:00:00 AM    ZD-21925
# 9990    3816  CA-2017-152471   7/8/2017 12:00:00 AM    ZD-21925
# 9991    5898  CA-2017-167682   4/3/2017 12:00:00 AM    ZD-21925
# 9992    5899  CA-2017-167682   4/3/2017 12:00:00 AM    ZD-21925
# 9993    8342  CA-2018-141481  6/11/2018 12:00:00 AM    ZD-21925
#
#            Customer Name   Segment        Country           City       State  \
# 0             Alex Avila  Consumer  United States    Minneapolis   Minnesota
# 1             Alex Avila  Consumer  United States    Minneapolis   Minnesota
# 2             Alex Avila  Consumer  United States  San Francisco  California
# 3             Alex Avila  Consumer  United States  San Francisco  California
# 4             Alex Avila  Consumer  United States  San Francisco  California
# ...                  ...       ...            ...            ...         ...
# 9989  Zuschuss Donatelli  Consumer  United States   Jacksonville     Florida
# 9990  Zuschuss Donatelli  Consumer  United States   Jacksonville     Florida
# 9991  Zuschuss Donatelli  Consumer  United States       Richmond     Indiana
# 9992  Zuschuss Donatelli  Consumer  United States       Richmond     Indiana
# 9993  Zuschuss Donatelli  Consumer  United States    Los Angeles  California
#
#       Postal Code   Region       Product ID         Category Sub-Category  \
# 0         55407.0  Central  OFF-AP-10000576  Office Supplies   Appliances
# 1         55407.0  Central  OFF-BI-10004654  Office Supplies      Binders
# 2         94109.0     West  OFF-ST-10001590  Office Supplies      Storage
# 3         94122.0     West  OFF-BI-10004390  Office Supplies      Binders
# 4         94122.0     West  OFF-AP-10002765  Office Supplies   Appliances
# ...           ...      ...              ...              ...          ...
# 9989      32216.0    South  TEC-PH-10002824       Technology       Phones
# 9990      32216.0    South  OFF-PA-10004965  Office Supplies        Paper
# 9991      47374.0  Central  FUR-FU-10003799        Furniture  Furnishings
# 9992      47374.0  Central  TEC-PH-10000673       Technology       Phones
# 9993      90036.0     West  OFF-AP-10004532  Office Supplies   Appliances
#
#                                            Product Name   Sales  Quantity  \
# 0                  Belkin 325VA UPS Surge Protector, 6'  362.94         3
# 1     Avery Binding System Hidden Tab Executive Styl...   11.54         2
# 2     Tenex Personal Project File with Scoop Front D...   26.96         2
# 3               GBC DocuBind 200 Manual Binding Machine  673.57         2
# 4     Fellowes Advanced Computer Series Surge Protec...   52.98         2
# ...                                                 ...     ...       ...
# 9989           Jabra SPEAK 410 Multidevice Speakerphone  823.96         5
# 9990                                         Xerox 1921   15.98         2
# 9991                     Seth Thomas 13 1/2" Wall Clock   71.12         4
# 9992     Plantronics Voyager Pro HD - Bluetooth Headset  259.96         4
# 9993  Kensington 6 Outlet Guardian Standard Surge Pr...   61.44         3
#
#       Discount  Profit
# 0          0.0   90.74
# 1          0.0    5.77
# 2          0.0    7.01
# 3          0.2  252.59
# 4          0.0   14.83
# ...        ...     ...
# 9989       0.2   51.50
# 9990       0.2    4.99
# 9991       0.0   22.05
# 9992       0.0  124.78
# 9993       0.0   16.59
#
# [9994 rows x 19 columns]

# %%
tabla_clientes
# Out:
#      Id_cliente              Nombre   Segmento
# 0      AA-10315          Alex Avila   Consumer
# 11     AA-10375        Allen Armold   Consumer
# 26     AA-10480        Andrew Allen   Consumer
# 38     AA-10645       Anna Andreadi   Consumer
# 56     AB-10015       Aaron Bergman   Consumer
# ...         ...                 ...        ...
# 9906   XP-21865        Xylona Preis   Consumer
# 9934   YC-21895      Yoseph Carroll  Corporate
# 9942   YS-21880       Yana Sorensen  Corporate
# 9954   ZC-21910    Zuschuss Carroll   Consumer
# 9985   ZD-21925  Zuschuss Donatelli   Consumer
#
# [793 rows x 3 columns]

# %%
join_table = tabla_super.merge(tabla_clientes, 
                                                                                               left_on='Customer ID',
                                                                                               right_on='Id_cliente',
                                                                                               how='inner')
join_table = join_table.drop(columns=['Customer ID','Customer Name', 'Segment','Nombre','Segmento'])
join_table
# Out:
#       Row ID        Order ID             Order Date        Country  \
# 0       1160  CA-2018-147039  6/29/2018 12:00:00 AM  United States
# 1       1161  CA-2018-147039  6/29/2018 12:00:00 AM  United States
# 2       1300  CA-2016-121391  10/4/2016 12:00:00 AM  United States
# 3       2230  CA-2015-128055  3/31/2015 12:00:00 AM  United States
# 4       2231  CA-2015-128055  3/31/2015 12:00:00 AM  United States
# ...      ...             ...                    ...            ...
# 9989    3815  CA-2017-152471   7/8/2017 12:00:00 AM  United States
# 9990    3816  CA-2017-152471   7/8/2017 12:00:00 AM  United States
# 9991    5898  CA-2017-167682   4/3/2017 12:00:00 AM  United States
# 9992    5899  CA-2017-167682   4/3/2017 12:00:00 AM  United States
# 9993    8342  CA-2018-141481  6/11/2018 12:00:00 AM  United States
#
#                City       State  Postal Code   Region       Product ID  \
# 0       Minneapolis   Minnesota      55407.0  Central  OFF-AP-10000576
# 1       Minneapolis   Minnesota      55407.0  Central  OFF-BI-10004654
# 2     San Francisco  California      94109.0     West  OFF-ST-10001590
# 3     San Francisco  California      94122.0     West  OFF-BI-10004390
# 4     San Francisco  California      94122.0     West  OFF-AP-10002765
# ...             ...         ...          ...      ...              ...
# 9989   Jacksonville     Florida      32216.0    South  TEC-PH-10002824
# 9990   Jacksonville     Florida      32216.0    South  OFF-PA-10004965
# 9991       Richmond     Indiana      47374.0  Central  FUR-FU-10003799
# 9992       Richmond     Indiana      47374.0  Central  TEC-PH-10000673
# 9993    Los Angeles  California      90036.0     West  OFF-AP-10004532
#
#              Category Sub-Category  \
# 0     Office Supplies   Appliances
# 1     Office Supplies      Binders
# 2     Office Supplies      Storage
# 3     Office Supplies      Binders
# 4     Office Supplies   Appliances
# ...               ...          ...
# 9989       Technology       Phones
# 9990  Office Supplies        Paper
# 9991        Furniture  Furnishings
# 9992       Technology       Phones
# 9993  Office Supplies   Appliances
#
#                                            Product Name   Sales  Quantity  \
# 0                  Belkin 325VA UPS Surge Protector, 6'  362.94         3
# 1     Avery Binding System Hidden Tab Executive Styl...   11.54         2
# 2     Tenex Personal Project File with Scoop Front D...   26.96         2
# 3               GBC DocuBind 200 Manual Binding Machine  673.57         2
# 4     Fellowes Advanced Computer Series Surge Protec...   52.98         2
# ...                                                 ...     ...       ...
# 9989           Jabra SPEAK 410 Multidevice Speakerphone  823.96         5
# 9990                                         Xerox 1921   15.98         2
# 9991                     Seth Thomas 13 1/2" Wall Clock   71.12         4
# 9992     Plantronics Voyager Pro HD - Bluetooth Headset  259.96         4
# 9993  Kensington 6 Outlet Guardian Standard Surge Pr...   61.44         3
#
#       Discount  Profit Id_cliente
# 0          0.0   90.74   AA-10315
# 1          0.0    5.77   AA-10315
# 2          0.0    7.01   AA-10315
# 3          0.2  252.59   AA-10315
# 4          0.0   14.83   AA-10315
# ...        ...     ...        ...
# 9989       0.2   51.50   ZD-21925
# 9990       0.2    4.99   ZD-21925
# 9991       0.0   22.05   ZD-21925
# 9992       0.0  124.78   ZD-21925
# 9993       0.0   16.59   ZD-21925
#
# [9994 rows x 17 columns]

# %%
join_table = join_table.merge(tabla_ubicacion, 
                                                                                               left_on='Postal Code',
                                                                                               right_on='Postal Code',
                                                                                               how='inner')

join_table
# Out:
#        Row ID        Order ID              Order Date      Country_x  \
# 0        1160  CA-2018-147039   6/29/2018 12:00:00 AM  United States
# 1        1161  CA-2018-147039   6/29/2018 12:00:00 AM  United States
# 2        1897  CA-2018-141789   10/3/2018 12:00:00 AM  United States
# 3        9218  US-2018-118157  11/14/2018 12:00:00 AM  United States
# 4        6885  CA-2016-120677   5/31/2016 12:00:00 AM  United States
# ...       ...             ...                     ...            ...
# 10028    5413  CA-2018-166856   9/18/2018 12:00:00 AM  United States
# 10029    3216  CA-2018-150189    7/8/2018 12:00:00 AM  United States
# 10030    4341  US-2015-129609   3/22/2015 12:00:00 AM  United States
# 10031    9835  CA-2017-126627  10/10/2017 12:00:00 AM  United States
# 10032    9836  CA-2017-126627  10/10/2017 12:00:00 AM  United States
#
#             City_x     State_x  Postal Code   Region       Product ID  \
# 0      Minneapolis   Minnesota      55407.0  Central  OFF-AP-10000576
# 1      Minneapolis   Minnesota      55407.0  Central  OFF-BI-10004654
# 2      Minneapolis   Minnesota      55407.0  Central  OFF-BI-10001359
# 3      Minneapolis   Minnesota      55407.0  Central  OFF-EN-10004459
# 4      Minneapolis   Minnesota      55407.0  Central  FUR-CH-10002320
# ...            ...         ...          ...      ...              ...
# 10028       Clovis  New Mexico      88101.0     West  TEC-AC-10004992
# 10029    San Mateo  California      94403.0     West  OFF-LA-10002762
# 10030      Portage     Indiana      46368.0  Central  OFF-AR-10003478
# 10031     La Porte       Texas      77571.0  Central  FUR-FU-10004963
# 10032     La Porte       Texas      77571.0  Central  OFF-BI-10001597
#
#               Category Sub-Category  \
# 0      Office Supplies   Appliances
# 1      Office Supplies      Binders
# 2      Office Supplies      Binders
# 3      Office Supplies    Envelopes
# 4            Furniture       Chairs
# ...                ...          ...
# 10028       Technology  Accessories
# 10029  Office Supplies       Labels
# 10030  Office Supplies          Art
# 10031        Furniture  Furnishings
# 10032  Office Supplies      Binders
#
#                                             Product Name    Sales  Quantity  \
# 0                   Belkin 325VA UPS Surge Protector, 6'   362.94         3
# 1      Avery Binding System Hidden Tab Executive Styl...    11.54         2
# 2             GBC DocuBind TL300 Electric Binding System  1793.98         2
# 3                                Security-Tint Envelopes    15.28         2
# 4                             Hon Pagoda Stacking Chairs  2567.84         8
# ...                                                  ...      ...       ...
# 10028         Kingston Digital DataTraveler 64GB USB 2.0   101.34         3
# 10029                                          Avery 485    75.18         6
# 10030  Avery Hi-Liter EverBold Pen Style Fluorescent ...    16.28         2
# 10031     Eldon 400 Class Desk Accessories, Black Carbon    14.00         4
# 10032  Wilson Jones Ledger-Size, Piano-Hinge Binder, ...    16.39         2
#
#        Discount  Profit Id_cliente      Country_y     State_y       City_y
# 0           0.0   90.74   AA-10315  United States   Minnesota  Minneapolis
# 1           0.0    5.77   AA-10315  United States   Minnesota  Minneapolis
# 2           0.0  843.17   AC-10450  United States   Minnesota  Minneapolis
# 3           0.0    7.49   AW-10930  United States   Minnesota  Minneapolis
# 4           0.0  770.35   BD-11320  United States   Minnesota  Minneapolis
# ...         ...     ...        ...            ...         ...          ...
# 10028       0.0    8.11   TS-21505  United States  New Mexico       Clovis
# 10029       0.0   35.33   VG-21790  United States  California    San Mateo
# 10030       0.0    6.51   VM-21835  United States     Indiana      Portage
# 10031       0.6   -6.30   WB-21850  United States       Texas     La Porte
# 10032       0.8  -26.23   WB-21850  United States       Texas     La Porte
#
# [10033 rows x 20 columns]

# %%
join_table = join_table.drop(columns=['Country_x','Country_y','City_x','City_y','State_x','State_y','Region'])
join_table
# Out:
#        Row ID        Order ID              Order Date  Postal Code  \
# 0        1160  CA-2018-147039   6/29/2018 12:00:00 AM      55407.0
# 1        1161  CA-2018-147039   6/29/2018 12:00:00 AM      55407.0
# 2        1897  CA-2018-141789   10/3/2018 12:00:00 AM      55407.0
# 3        9218  US-2018-118157  11/14/2018 12:00:00 AM      55407.0
# 4        6885  CA-2016-120677   5/31/2016 12:00:00 AM      55407.0
# ...       ...             ...                     ...          ...
# 10028    5413  CA-2018-166856   9/18/2018 12:00:00 AM      88101.0
# 10029    3216  CA-2018-150189    7/8/2018 12:00:00 AM      94403.0
# 10030    4341  US-2015-129609   3/22/2015 12:00:00 AM      46368.0
# 10031    9835  CA-2017-126627  10/10/2017 12:00:00 AM      77571.0
# 10032    9836  CA-2017-126627  10/10/2017 12:00:00 AM      77571.0
#
#             Product ID         Category Sub-Category  \
# 0      OFF-AP-10000576  Office Supplies   Appliances
# 1      OFF-BI-10004654  Office Supplies      Binders
# 2      OFF-BI-10001359  Office Supplies      Binders
# 3      OFF-EN-10004459  Office Supplies    Envelopes
# 4      FUR-CH-10002320        Furniture       Chairs
# ...                ...              ...          ...
# 10028  TEC-AC-10004992       Technology  Accessories
# 10029  OFF-LA-10002762  Office Supplies       Labels
# 10030  OFF-AR-10003478  Office Supplies          Art
# 10031  FUR-FU-10004963        Furniture  Furnishings
# 10032  OFF-BI-10001597  Office Supplies      Binders
#
#                                             Product Name    Sales  Quantity  \
# 0                   Belkin 325VA UPS Surge Protector, 6'   362.94         3
# 1      Avery Binding System Hidden Tab Executive Styl...    11.54         2
# 2             GBC DocuBind TL300 Electric Binding System  1793.98         2
# 3                                Security-Tint Envelopes    15.28         2
# 4                             Hon Pagoda Stacking Chairs  2567.84         8
# ...                                                  ...      ...       ...
# 10028         Kingston Digital DataTraveler 64GB USB 2.0   101.34         3
# 10029                                          Avery 485    75.18         6
# 10030  Avery Hi-Liter EverBold Pen Style Fluorescent ...    16.28         2
# 10031     Eldon 400 Class Desk Accessories, Black Carbon    14.00         4
# 10032  Wilson Jones Ledger-Size, Piano-Hinge Binder, ...    16.39         2
#
#        Discount  Profit Id_cliente
# 0           0.0   90.74   AA-10315
# 1           0.0    5.77   AA-10315
# 2           0.0  843.17   AC-10450
# 3           0.0    7.49   AW-10930
# 4           0.0  770.35   BD-11320
# ...         ...     ...        ...
# 10028       0.0    8.11   TS-21505
# 10029       0.0   35.33   VG-21790
# 10030       0.0    6.51   VM-21835
# 10031       0.6   -6.30   WB-21850
# 10032       0.8  -26.23   WB-21850
#
# [10033 rows x 13 columns]

# %%
join_table = join_table.merge(tabla_producto, 
                                                                                               left_on='Postal Code',
                                                                                               right_on='Postal Code',
                                                                                               how='inner')

join_table

# %%
tabla_producto
# Out:
#            Product ID         Category Sub-Category  \
# 0     OFF-AP-10000576  Office Supplies   Appliances
# 1     OFF-BI-10004654  Office Supplies      Binders
# 2     OFF-ST-10001590  Office Supplies      Storage
# 3     OFF-BI-10004390  Office Supplies      Binders
# 4     OFF-AP-10002765  Office Supplies   Appliances
# ...               ...              ...          ...
# 9744  OFF-AP-10001124  Office Supplies   Appliances
# 9795  OFF-ST-10001414  Office Supplies      Storage
# 9818  TEC-PH-10001468       Technology       Phones
# 9881  TEC-MA-10003246       Technology     Machines
# 9986  TEC-PH-10001949       Technology       Phones
#
#                                            Product Name
# 0                  Belkin 325VA UPS Surge Protector, 6'
# 1     Avery Binding System Hidden Tab Executive Styl...
# 2     Tenex Personal Project File with Scoop Front D...
# 3               GBC DocuBind 200 Manual Binding Machine
# 4     Fellowes Advanced Computer Series Surge Protec...
# ...                                                 ...
# 9744  Belkin 8 Outlet SurgeMaster II Gold Surge Prot...
# 9795              Decoflex Hanging Personal Folder File
# 9818             Panasonic Business Telephones KX-T7736
# 9881              Hewlett-Packard Deskjet D4360 Printer
# 9986                            Cisco SPA 501G IP Phone
#
# [1894 rows x 4 columns]

# %%
join_table
# Out:
#        Row ID        Order ID              Order Date  Postal Code  \
# 0        1160  CA-2018-147039   6/29/2018 12:00:00 AM      55407.0
# 1        1161  CA-2018-147039   6/29/2018 12:00:00 AM      55407.0
# 2        1897  CA-2018-141789   10/3/2018 12:00:00 AM      55407.0
# 3        9218  US-2018-118157  11/14/2018 12:00:00 AM      55407.0
# 4        6885  CA-2016-120677   5/31/2016 12:00:00 AM      55407.0
# ...       ...             ...                     ...          ...
# 10028    5413  CA-2018-166856   9/18/2018 12:00:00 AM      88101.0
# 10029    3216  CA-2018-150189    7/8/2018 12:00:00 AM      94403.0
# 10030    4341  US-2015-129609   3/22/2015 12:00:00 AM      46368.0
# 10031    9835  CA-2017-126627  10/10/2017 12:00:00 AM      77571.0
# 10032    9836  CA-2017-126627  10/10/2017 12:00:00 AM      77571.0
#
#             Product ID         Category Sub-Category  \
# 0      OFF-AP-10000576  Office Supplies   Appliances
# 1      OFF-BI-10004654  Office Supplies      Binders
# 2      OFF-BI-10001359  Office Supplies      Binders
# 3      OFF-EN-10004459  Office Supplies    Envelopes
# 4      FUR-CH-10002320        Furniture       Chairs
# ...                ...              ...          ...
# 10028  TEC-AC-10004992       Technology  Accessories
# 10029  OFF-LA-10002762  Office Supplies       Labels
# 10030  OFF-AR-10003478  Office Supplies          Art
# 10031  FUR-FU-10004963        Furniture  Furnishings
# 10032  OFF-BI-10001597  Office Supplies      Binders
#
#                                             Product Name    Sales  Quantity  \
# 0                   Belkin 325VA UPS Surge Protector, 6'   362.94         3
# 1      Avery Binding System Hidden Tab Executive Styl...    11.54         2
# 2             GBC DocuBind TL300 Electric Binding System  1793.98         2
# 3                                Security-Tint Envelopes    15.28         2
# 4                             Hon Pagoda Stacking Chairs  2567.84         8
# ...                                                  ...      ...       ...
# 10028         Kingston Digital DataTraveler 64GB USB 2.0   101.34         3
# 10029                                          Avery 485    75.18         6
# 10030  Avery Hi-Liter EverBold Pen Style Fluorescent ...    16.28         2
# 10031     Eldon 400 Class Desk Accessories, Black Carbon    14.00         4
# 10032  Wilson Jones Ledger-Size, Piano-Hinge Binder, ...    16.39         2
#
#        Discount  Profit Id_cliente
# 0           0.0   90.74   AA-10315
# 1           0.0    5.77   AA-10315
# 2           0.0  843.17   AC-10450
# 3           0.0    7.49   AW-10930
# 4           0.0  770.35   BD-11320
# ...         ...     ...        ...
# 10028       0.0    8.11   TS-21505
# 10029       0.0   35.33   VG-21790
# 10030       0.0    6.51   VM-21835
# 10031       0.6   -6.30   WB-21850
# 10032       0.8  -26.23   WB-21850
#
# [10033 rows x 13 columns]

# %%
join_table = join_table.merge(tabla_clientes, 
                                                                                               left_on='Postal Code',
                                                                                               right_on='Postal Code',
                                                                                               how='inner')

join_table
